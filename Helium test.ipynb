# %%
from bs4 import BeautifulSoup
from helium import *
import time 

def scrape1():
    url = 'https://sam.gov/content/home'
    driver = start_chrome(url, headless = True)
    driver.get(url)
        
    time.sleep(5)
    
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    announcments = soup.find("div", {"class" : "sds-feed"})
    article_links = []
    title = []
    date = []
    preview = []
    for a in announcments.find_all('a', href=True):      
        article_links.append(a['href'])
        for strong in a.find_all('strong'):
            title.append(strong.text)
        for div in a.find_all('div',{"class": "date"}):
            date.append(div.text)
    for i in range(0,5,1):
        preview = article_links[i] + " " + title[i] + " " + date[i]
        print(preview)
            
scrape1()
# Out:
# https://www.fsd.gov/gsafsd_sp?id=kb_article_view&sysparm_article=KB0046482 New! You can get a Unique Entity ID (SAM) on SAM.gov Oct 15
# https://interact.gsa.gov/blog/help-resources-uei-transition-now-available-fsdgov Unique Entity ID (SAM) Help Resources Available Oct 15
# https://www.fsd.gov/ How to Find Help for SAM.gov Oct 15
# https://www.fsd.gov/gsafsd_sp?id=kb_article_view&sysparm_article=KB0047778 New Guidance on COVID-⁠19 Workplace Safety for Federal Contractors Oct 1
# https://www.fsd.gov/gsafsd_sp?id=kb_article_view&sysparm_article=KB0044736 New FPS-Protected Federal Facility Entrance Requirements Sep 1

# %%
from bs4 import BeautifulSoup
from helium import *
import time 

def scrape1():
    url = 'https://sam.gov/content/home'
    driver = start_chrome(url, headless = True)
    driver.get(url)
        
    time.sleep(5)
    
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    announcments = soup.find("div", {"class" : "sds-feed"})
    article_links = []
    title = []
    date = []
    preview = []
    for a in announcments.find_all('a', href=True):      
        article_links.append(a['href'])
        for strong in a.find_all('strong'):
            title.append(strong.text)
        for div in a.find_all('div',{"class": "date"}):
            date.append(div.text)
        
    for i in article_links:
        link = i
        driver_link = start_chrome(link,headless = True)
        driver_link.get(link)
        
        time.sleep(5)
        
        html_link = driver_link.page_source
        soup = BeautifulSoup(html, "html.parser")
        text = soup.find_all('div', {'class':'field-item even'})
        print(soup)  
        
scrape1()
# Out:
# <html class="cdk-global-scrollblock" lang="en" style="left: 0px; top: 0px;"><head>
# <meta charset="utf-8"/>
# <title>SAM.gov | Home</title>
# <meta content="xE0DDLEdhn7JcYFfoRocOPDm6K0kvCOXsjwFLJjBwWY" name="google-site-verification"/>
# <base href="/content/"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="favicon.ico" rel="icon" type="image/x-icon"/>
# ...
